# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmiyasasikumar11/DSA_Problems/blob/main/Railway_Cancellation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("Q39_railway_cancellation (1).csv")
data.head()
# Out:
#   booking_id journey_date booking_class  advance_booking_days  \
# 0    RB00001   2026-01-18            2A                  26.0
# 1    RB00002   2026-02-20            2A                  78.0
# 2    RB00003   2026-06-14            3A                  12.0
# 3    RB00004   2026-07-30       Sleeper                  24.0
# 4    RB00005   2026-03-30            1A                  55.0
#
#    ticket_price_inr passenger_category cancellation_status
# 0              3323             Senior           Travelled
# 1              1227              Adult           Cancelled
# 2              1711             Senior           Cancelled
# 3              1279              Adult           Travelled
# 4              3508            Student           Travelled

# %%
print(data.shape)
print(data.column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1905/938508404.py in <cell line: 0>()
# ----> 1 print(data.shape)
#       2 print(data.column)
#
# NameError: name 'data' is not defined

# %%
print(data.columns)
# Out:
# Index(['booking_id', 'journey_date', 'booking_class', 'advance_booking_days',
#        'ticket_price_inr', 'passenger_category', 'cancellation_status'],
#       dtype='object')

# %%
print(data.shape)
# Out:
# (123, 7)

# %%
print(data.head())
# Out:
#   booking_id journey_date booking_class  advance_booking_days  \
# 0    RB00001   2026-01-18            2A                  26.0
# 1    RB00002   2026-02-20            2A                  78.0
# 2    RB00003   2026-06-14            3A                  12.0
# 3    RB00004   2026-07-30       Sleeper                  24.0
# 4    RB00005   2026-03-30            1A                  55.0
#
#    ticket_price_inr passenger_category cancellation_status
# 0              3323             Senior           Travelled
# 1              1227              Adult           Cancelled
# 2              1711             Senior           Cancelled
# 3              1279              Adult           Travelled
# 4              3508            Student           Travelled

# %%
print(data['cancellation_status'].value_counts())
# Out:
# cancellation_status
# Travelled    107
# Cancelled     16
# Name: count, dtype: int64

# %%
print(data.isnull().sum())
# Out:
# booking_id              0
# journey_date            1
# booking_class           0
# advance_booking_days    1
# ticket_price_inr        0
# passenger_category      1
# cancellation_status     0
# dtype: int64

# %%
print(data.describe())
# Out:
#        advance_booking_days  ticket_price_inr
# count            122.000000        123.000000
# mean              40.483607       2245.577236
# std               24.627551       1111.737504
# min                0.000000        299.000000
# 25%               22.000000       1244.500000
# 50%               43.500000       2193.000000
# 75%               60.000000       3262.000000
# max               90.000000       4122.000000

# %%
print(data['cancellation_status'].value_counts())
# Out:
# cancellation_status
# Travelled    107
# Cancelled     16
# Name: count, dtype: int64

# %%
cancelled = (data['cancellationstatus'] == 'Cancelled').sum()
total = len(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cancellationstatus'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1905/690177287.py in <cell line: 0>()
# ...

# %%
data['fare_per_booking_day'] = data['ticket_price_inr'] / data['advance_booking_days']

# %%
print(data[['ticket_price_inr', 'advance_booking_days', 'fare_per_booking_day']].head())
# Out:
#    ticket_price_inr  advance_booking_days  fare_per_booking_day
# 0              3323                  26.0            127.807692
# 1              1227                  78.0             15.730769
# 2              1711                  12.0            142.583333
# 3              1279                  24.0             53.291667
# 4              3508                  55.0             63.781818

# %%
cancelled = (data['cancellation_status'] == 'Cancelled').sum()
total = len(data)

# %%
print("Cancellation percentage:", cancelled/total*100)
# Out:
# Cancellation percentage: 13.008130081300814
